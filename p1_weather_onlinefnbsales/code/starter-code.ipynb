# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](../data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](../data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`rainfall-monthly-highest-daily-total.csv`](../data/rainfall-monthly-highest-daily-total.csv): Monthly maximum rainfall in a day from 1982 to 2022.
# * [`rainfall-monthly-number-of-rain-days.csv`](../data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2024.
# * [`rainfall-monthly-total.csv`](../data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022.
# * [`relative-humidity-monthly-mean.csv`](../data/relative-humidity-monthly-mean.csv): Monthly mean relative humidity from 1982 to 2022.
# * [`wet-bulb-temperature-hourly.csv`](../data/wet-bulb-temperature-hourly.csv): Hourly wet bulb temperature from 1982 to 2022.
# * [`surface-air-temperature-monthly-mean.csv`](../data/surface-air-temperature-monthly-mean.csv): Monthly mean surface air temperature from 1982 to 2022.
#
# I have included an additional dataset in the [`data`](./data/) folder for this project. It correponds to Online Food and Beverage (F&B) Sales Proportion information, obtained from [SingStat](https://tablebuilder.singstat.gov.sg/table/TS/M602001).
#
# * [`online-fnb-sales-proportion.csv`](../data/online-fnb-sales-proportion.csv): Monthly proportion of online F&B sales to total F&B sales (in percentage).

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# I am working as a Data Analyst for some F&B businesses. In this project, we will analyse how and when weather changes affect online F&B businesses. For example, on rainy days, do online F&B sales proportion go up?
#
# The ideal outcome is to provide the F&B businesses with relevant information to manage resources as rainy conditions and temperature fluctuates in different parts of the year.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# "A foodpanda spokesman said the weather and factors such as restaurant promotions for the festive season could have caused the spike in the number of orders seen last week." [The Straits Times, Dec 2019](https://www.straitstimes.com/singapore/wet-weather-in-singapore-some-businesses-hit-hard-others-doing-fine)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# test = [2, 3, 65, 2, 123, 44, 93, 64, 91, 82]
def calculate_mean(list_of_values):
    total = 0
    for value in list_of_values:
        total += value
    return total / len(list_of_values)
# calculate_mean(test)

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_std(list_of_values):
    total = 0
    for value in list_of_values:
        difference = value - calculate_mean(list_of_values)
        total += (difference)**2
    return (total / len(list_of_values))**0.5
# calculate_std(test)

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
rain_highest = pd.read_csv('../data/rainfall-monthly-highest-daily-total.csv')
rain_highest.head() # until 2022 November
# Out:
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0

# %%
rain_highest.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      491 non-null    object
#  1   maximum_rainfall_in_a_day  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
rain_days = pd.read_csv('../data/rainfall-monthly-number-of-rain-days.csv')
rain_days.head() # until 2024 January
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
rain_days.info() # no missing values and correct type: integer
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             505 non-null    object
#  1   no_of_rainy_days  505 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.0+ KB

# %%
rain_total = pd.read_csv('../data/rainfall-monthly-total.csv')
rain_total.head() # until 2022 August
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
rain_total.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           488 non-null    object
#  1   total_rainfall  488 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
humid = pd.read_csv('../data/relative-humidity-monthly-mean.csv')
humid.head() # until 2022 November
# Out:
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2

# %%
humid.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    491 non-null    object
#  1   mean_rh  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
wet_bulb = pd.read_csv('../data/wet-bulb-temperature-hourly.csv')
wet_bulb.head() # until 2022 November
wet_bulb["wbt_date"] = pd.to_datetime(wet_bulb.wbt_date) # change to datetime format
wet_bulb["month"] = wet_bulb['wbt_date'].dt.strftime('%Y-%m') # change to YYYY-mm format
wet_bulb = wet_bulb.groupby("month")[["wet_bulb_temperature"]].mean() # find the mean temperature of each month
wet_bulb = wet_bulb.reset_index()
wet_bulb.head()
# Out:
#      month  wet_bulb_temperature
# 0  1982-01             23.456048
# 1  1982-02             24.297619
# 2  1982-03             24.811559
# 3  1982-04             25.103750
# 4  1982-05             25.689651

# %%
wet_bulb.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   month                 491 non-null    object
#  1   wet_bulb_temperature  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
surface_air_temp = pd.read_csv('../data/surface-air-temperature-monthly-mean.csv')
surface_air_temp.head() # until 2022 November
# Out:
#      month  mean_temp
# 0  1982-01       25.9
# 1  1982-02       27.1
# 2  1982-03       27.2
# 3  1982-04       27.0
# 4  1982-05       28.0

# %%
surface_air_temp.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      491 non-null    object
#  1   mean_temp  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
fnb = pd.read_csv('../data/online-fnb-sales-proportion_cleaned.csv') # removed the redundant items in csv file
fnb.head() # 2019 Jan to 2023 Dec in descending order
# Out:
#   Data Series  Food & Beverage Services (Percentage)
# 0    2023 Dec                                   23.3
# 1    2023 Nov                                   23.4
# 2    2023 Oct                                   23.6
# 3    2023 Sep                                   23.0
# 4    2023 Aug                                   23.0

# %%
fnb.info() # no missing values and correct type: float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Data Series                            60 non-null     object
#  1   Food & Beverage Services (Percentage)  60 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
# change column name and values for fnb dataframe
fnb.rename(columns={'Data Series': 'month'}, inplace=True)
# change values of 'month' to match with other dataframes
fnb['month'] = fnb['month'].str.replace(' Dec', '-12')
fnb['month'] = fnb['month'].str.replace(' Nov', '-11')
fnb['month'] = fnb['month'].str.replace(' Oct', '-10')
fnb['month'] = fnb['month'].str.replace(' Sep', '-09')
fnb['month'] = fnb['month'].str.replace(' Aug', '-08')
fnb['month'] = fnb['month'].str.replace(' Jul', '-07')
fnb['month'] = fnb['month'].str.replace(' Jun', '-06')
fnb['month'] = fnb['month'].str.replace(' May', '-05')
fnb['month'] = fnb['month'].str.replace(' Apr', '-04')
fnb['month'] = fnb['month'].str.replace(' Mar', '-03')
fnb['month'] = fnb['month'].str.replace(' Feb', '-02')
fnb['month'] = fnb['month'].str.replace(' Jan', '-01')
# rearrange month from earliest to latest
fnb.sort_values(by='month', inplace=True)
fnb.reset_index(drop=True, inplace=True)
fnb.head()
# Out:
#      month  Food & Beverage Services (Percentage)
# 0  2019-01                                    7.3
# 1  2019-02                                    7.4
# 2  2019-03                                    8.1
# 3  2019-04                                    8.2
# 4  2019-05                                    8.1

# %%
df = pd.merge(rain_highest, rain_days, on='month', how='inner') 
# inner join (ignoring the rows where month doesnt tally)
df = pd.merge(df, rain_total, on='month', how='inner')
df = pd.merge(df, humid, on='month', how='inner')
df = pd.merge(df, wet_bulb, on='month', how='inner')
df = pd.merge(df, surface_air_temp, on='month', how='inner')
df = pd.merge(df, fnb, on='month', how='inner')
new_column_dict = {'Food & Beverage Services (Percentage)': 'online_f&b_sales_proportion', 'month': 'year-month'}
df.rename(columns=new_column_dict, inplace=True) # renaming column as lowercase and 'month' as 'year-month'
df.head()
# Out:
#   year-month  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0    2019-01                       38.2                 9            63.6
# 1    2019-02                       13.4                 5            31.6
# 2    2019-03                       29.0                 6            72.2
# 3    2019-04                       52.4                 9           174.8
# 4    2019-05                       17.2                13            69.0
#
#    mean_rh  wet_bulb_temperature  mean_temp  online_f&b_sales_proportion
# 0     75.6             24.605376       28.0                          7.3
# 1     74.1             24.581696       28.2                          7.4
# 2     72.3             24.737500       28.7                          8.1
# 3     77.6             25.502778       28.6                          8.2
# 4     79.2             26.341935       29.3                          8.1

# %%
df.to_csv('merged_df.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |maximum_rainfall_in_a_day|float|rainfall-monthly-highest-daily-total| The highest rainfall in a day for each month in mm|
# |no_of_rainy_days|integer|rainfall-monthly-number-of-rain-days|Number of rainy days in each month|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# |mean_rh|float|relative-humidity-monthly-mean|Mean relative humidity in percentage|
# |wet_bulb_temperature|float|wet-bulb-temperature-hourly|Mean wet bulb temperature of each month (converted from wet bulb temperature hourly)|
# |mean_temp|float|surface-air-temperature-monthly-mean|Mean surface air temperature of each month|
# |online_f&b_sales_proportion|float|online-fnb-sales-proportion_cleaned|Percentage of online F&B sales to total F&B sales|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# 1 summary statistics
df.describe()
# Out:
#        maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall    mean_rh  \
# count                  44.000000         44.000000       44.000000  44.000000
# mean                   46.790909         13.727273      166.856818  77.838636
# std                    33.069875          5.345564      120.877288   2.630078
# min                     0.600000          2.000000        1.000000  72.100000
# 25%                    29.450000          9.000000       92.150000  76.475000
# 50%                    42.800000         14.000000      156.700000  77.850000
# 75%                    58.950000         17.000000      214.000000  79.350000
# max                   210.600000         24.000000      692.800000  83.900000
#
#        wet_bulb_temperature  mean_temp  online_f&b_sales_proportion
# count             44.000000  44.000000                    44.000000
# mean              25.079624  28.118182                    22.984091
# ...

# %%
# 2 use dictionary comprehension to apply the sd function
column_values = df.columns[1:]
sd = {col: calculate_std(df[col]) for col in column_values}
print(sd)
print(np.std(df['maximum_rainfall_in_a_day'])) # using numpy to calculate sd
df['maximum_rainfall_in_a_day'].std() # using pandas to calculator sd
# my function and numpy calculate using "population sd" (which divides by n before square rooting)
# pandas calculate using "sample population sd" (which divides by n-1 before square rooting)
# Out:
# {'maximum_rainfall_in_a_day': 32.691921563854116, 'no_of_rainy_days': 5.284469683394044, 'total_rainfall': 119.4957880538193, 'mean_rh': 2.600018873103784, 'wet_bulb_temperature': 0.5131536074869333, 'mean_temp': 0.6729422261007417, 'online_f&b_sales_proportion': 11.609242853351772}
# 32.691921563854116
# 33.0698754097963

# %%
# 3 investigate trends in the data
# a
rain_total_1990 = rain_total[rain_total['month'].str.contains('1990')] # using "string contains" to filter the data
rain_total_1990.sort_values(by='total_rainfall') # sorting by column 'total_rainfall'
# Out:
#        month  total_rainfall
# 97   1990-02            24.1
# 99   1990-04            52.4
# 105  1990-10            56.4
# 98   1990-03            94.2
# 101  1990-06           112.6
# 102  1990-07           124.0
# 103  1990-08           146.6
# 96   1990-01           147.4
# 100  1990-05           180.1
# 106  1990-11           180.4
# 107  1990-12           201.1
# 104  1990-09           204.5

# %%
# 3 investigate trends in the data
# a
rain_total_2000 = rain_total[rain_total['month'].str.contains('2000')] # using "string contains" to filter the data
rain_total_2000.sort_values(by='total_rainfall') # sorting by column 'total_rainfall'
# Out:
#        month  total_rainfall
# 224  2000-09            81.1
# 220  2000-05            96.8
# 223  2000-08           113.5
# 222  2000-07           116.1
# 225  2000-10           120.9
# 221  2000-06           157.5
# 227  2000-12           236.0
# 217  2000-02           237.8
# 218  2000-03           238.3
# 216  2000-01           275.2
# 219  2000-04           311.6
# 226  2000-11           385.7

# %%
# 3 investigate trends in the data
# a
rain_total_2010 = rain_total[rain_total['month'].str.contains('2010')] # using "string contains" to filter the data
rain_total_2010.sort_values(by='total_rainfall') # sorting by column 'total_rainfall'
# Out:
#        month  total_rainfall
# 337  2010-02             6.3
# 336  2010-01            69.5
# 344  2010-09           121.5
# 340  2010-05           157.5
# 343  2010-08           158.4
# 339  2010-04           158.5
# 345  2010-10           166.2
# 347  2010-12           181.4
# 338  2010-03           238.0
# 341  2010-06           240.5
# 346  2010-11           278.8
# 342  2010-07           298.5

# %%
# 3 investigate trends in the data
# a
rain_total_2020 = rain_total[rain_total['month'].str.contains('2020')] # using "string contains" to filter the data
rain_total_2020.sort_values(by='total_rainfall') # sorting by column 'total_rainfall'
# Out:
#        month  total_rainfall
# 457  2020-02            65.0
# 465  2020-10            78.8
# 456  2020-01            88.4
# 463  2020-08           103.4
# 458  2020-03           108.8
# 462  2020-07           140.8
# 464  2020-09           150.2
# 459  2020-04           188.0
# 466  2020-11           220.6
# 461  2020-06           233.8
# 467  2020-12           253.2
# 460  2020-05           255.6

# %% [markdown]
# In 1990, highest total rainfall was in September and the lowest was in February. \
# In 2000, highest total rainfall was in November and the lowest was in September. \
# In 2010, highest total rainfall was in July and the lowest was in February. \
# In 2020, highest total rainfall was in May and the lowest was in February.

# %%
# 3 investigate trends in the data
# b
# my range of analysis is from 2019 January to 2022 August
df['year_2019'] = df['year-month'].str.contains('2019').astype(int)  # create new columns and use boolean filtering
df['year_2020'] = df['year-month'].str.contains('2020').astype(int)
df['year_2021'] = df['year-month'].str.contains('2021').astype(int)
df['year_2022'] = df['year-month'].str.contains('2022').astype(int)
# find total sum of rainfall for each year from 2019 to 2022
# 2022 data is until August
print(f"Total rainfall in 2019 is {df.groupby('year_2019')['total_rainfall'].sum()[1]}.")
print(f"Total rainfall in 2020 is {df.groupby('year_2020')['total_rainfall'].sum()[1]}.")
print(f"Total rainfall in 2021 is {df.groupby('year_2021')['total_rainfall'].sum()[1]}.")
print(f"Total rainfall in 2022 is {df.groupby('year_2022')['total_rainfall'].sum()[1]}.")
# Out:
# Total rainfall in 2019 is 1367.5.
# Total rainfall in 2020 is 1886.6.
# Total rainfall in 2021 is 2809.6.
# Total rainfall in 2022 is 1278.0.

# %% [markdown]
# The highest total rainfall was in 2021. \
# The lowest total rainfall was in 2022. Note: The data for 2022 is only until August.

# %%
# 3 investigate trends in the data
# c
rain_days_1990 = rain_days[rain_days['month'].str.contains('1990')] # using "string contains" to filter the data
rain_days_1990.sort_values(by='no_of_rainy_days') # sorting by column 'no_of_rainy_days'
# Out:
#        month  no_of_rainy_days
# 98   1990-03                 4
# 97   1990-02                 8
# 101  1990-06                 9
# 99   1990-04                10
# 100  1990-05                11
# 102  1990-07                12
# 105  1990-10                12
# 96   1990-01                13
# 103  1990-08                13
# 107  1990-12                16
# 104  1990-09                17
# 106  1990-11                17

# %%
# 3 investigate trends in the data
# c
rain_days_2000 = rain_days[rain_days['month'].str.contains('2000')] # using "string contains" to filter the data
rain_days_2000.sort_values(by='no_of_rainy_days') # sorting by column 'no_of_rainy_days'
# Out:
#        month  no_of_rainy_days
# 220  2000-05                10
# 222  2000-07                12
# 224  2000-09                12
# 216  2000-01                14
# 225  2000-10                14
# 218  2000-03                15
# 221  2000-06                16
# 217  2000-02                18
# 223  2000-08                18
# 227  2000-12                18
# 219  2000-04                20
# 226  2000-11                21

# %%
# 3 investigate trends in the data
# c
rain_days_2010 = rain_days[rain_days['month'].str.contains('2010')] # using "string contains" to filter the data
rain_days_2010.sort_values(by='no_of_rainy_days') # sorting by column 'no_of_rainy_days'
# Out:
#        month  no_of_rainy_days
# 337  2010-02                 4
# 336  2010-01                10
# 338  2010-03                11
# 344  2010-09                13
# 347  2010-12                14
# 343  2010-08                16
# 340  2010-05                17
# 345  2010-10                17
# 339  2010-04                18
# 342  2010-07                18
# 341  2010-06                19
# 346  2010-11                21

# %%
# 3 investigate trends in the data
# c
rain_days_2020 = rain_days[rain_days['month'].str.contains('2020')] # using "string contains" to filter the data
rain_days_2020.sort_values(by='no_of_rainy_days') # sorting by column 'no_of_rainy_days'
# Out:
#        month  no_of_rainy_days
# 456  2020-01                 6
# 457  2020-02                 8
# 458  2020-03                 8
# 459  2020-04                12
# 463  2020-08                12
# 460  2020-05                16
# 465  2020-10                16
# 464  2020-09                18
# 466  2020-11                19
# 467  2020-12                20
# 461  2020-06                21
# 462  2020-07                22

# %% [markdown]
# In 1990, highest number of rainy days was in November/September and the lowest was in March. \
# In 2000, highest number of rainy days was in November and the lowest was in May. \
# In 2010, highest number of rainy days was in November and the lowest was in February. \
# In 2020, highest number of rainy days was in July and the lowest was in January.

# %%
# 3 investigate trends in the data
# d
# my range of analysis is from 2019 January to 2022 August, and alr created boolean filtering columns
# find total sum of rainy days for each year from 2019 to 2022
# 2022 data is until Aug only
print(f"Total number of rainy days in 2019 is {df.groupby('year_2019')['no_of_rainy_days'].sum()[1]}.")
print(f"Total number of rainy days in 2020 is {df.groupby('year_2020')['no_of_rainy_days'].sum()[1]}.")
print(f"Total number of rainy days in 2021 is {df.groupby('year_2021')['no_of_rainy_days'].sum()[1]}.")
print(f"Total number of rainy days in 2022 is {df.groupby('year_2022')['no_of_rainy_days'].sum()[1]}.")
# Out:
# Total number of rainy days in 2019 is 120.
# Total number of rainy days in 2020 is 178.
# Total number of rainy days in 2021 is 182.
# Total number of rainy days in 2022 is 124.

# %% [markdown]
# The highest total rainfall was in 2021. \
# The lowest total rainfall was in 2019.

# %%
# 3 investigate trends in the data (outliers)
# e
# remove the boolean filtering columns
df = df.drop(columns=['year_2019', 'year_2020', 'year_2021', 'year_2022'])

# %%
# pandas set by default the whiskers to be 1.5*IQR or 1.5*STD from the edges of the box
# outliers would be smaller than mean - 1.5*std or larger than mean + 1.5*std
box_whisker = sns.boxplot(df, orient='h')
box_whisker.set_title('Boxplots of each column')
box_whisker.set_xlabel("value");

# %% [markdown]
# There is an outlier for the 'maximum_rainfall_in_a_day' column. \
# There are two outliers for the 'total_rainfall' column, 421.5 in Dec 2019 and 692.5 in Jan 2021.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
# plot histogram of rainfall data with bins=5
rain_days["no_of_rainy_days"].plot(kind='hist', bins=5).set_title('Histogram of No. of Rainy Days with 5 bins');

# %%
# plot histogram of rainfall data with bins=20
rain_days["no_of_rainy_days"].plot(kind='hist', bins=20).set_title('Histogram of No. of Rainy Days with 20 bins');

# %%
# plot histogram of rainfall data with bins=30
rain_days["no_of_rainy_days"].plot(kind='hist', bins=30).set_title('Histogram of No. of Rainy Days with 30 bins');

# %% [markdown]
# The distribution for the Number of Rainy Days variable is centred.

# %%
df['year'] = df['year-month'].map(lambda date: date[0:4]) # create new column called 'year' by slicing string
df['month'] = df['year-month'].map(lambda date: date[-2:]) # create new column called 'month' by slicing string
df.head()
# Out:
#   year-month  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0    2019-01                       38.2                 9            63.6
# 1    2019-02                       13.4                 5            31.6
# 2    2019-03                       29.0                 6            72.2
# 3    2019-04                       52.4                 9           174.8
# 4    2019-05                       17.2                13            69.0
#
#    mean_rh  wet_bulb_temperature  mean_temp  online_f&b_sales_proportion  \
# 0     75.6             24.605376       28.0                          7.3
# 1     74.1             24.581696       28.2                          7.4
# 2     72.3             24.737500       28.7                          8.1
# 3     77.6             25.502778       28.6                          8.2
# 4     79.2             26.341935       29.3                          8.1
#
#    year month
# 0  2019    01
# 1  2019    02
# 2  2019    03
# 3  2019    04
# ...

# %%
# plot line graph 
df.groupby('month')[['maximum_rainfall_in_a_day', 'no_of_rainy_days', 'total_rainfall', 'online_f&b_sales_proportion', 'mean_rh', 'wet_bulb_temperature', 'mean_temp']].mean().plot(figsize=(15,8));
# use groupby to find mean value of each column in Jan, mean value of each column in Feb, etc
# observe trends throughout each year, from January to December

# %% [markdown]
# Comparing the red line (online_f&b_sales_proportion) to other lines in the Line Graph above, there are no distinct and clear relationships that we can spot. Since Online F&B sales proportion is a percentage value and its values are ranging around 0% to 30% only, we can try scaling down to plot only the red line (online_f&b_sales_proportion) and orange line (no. of rainy days) on the same diagram.

# %%
# plot line graph 
ax_line = df.groupby('month')[['no_of_rainy_days', 'online_f&b_sales_proportion']].mean().plot(ylabel='Percentage', xlabel='Month', figsize=(15,8));
# use groupby to find mean value of each column in Jan, mean value of each column in Feb, etc
# observe trends throughout each year, from January to December
ax_line.set_title('Trends of Number of Rainy Days & Online F&B Sales Proportion', fontsize=21);
ax_line2 = ax_line.twinx()
ax_line2.set_ylabel('Mean Number of Rainy Days')
ax_line2.set_ylim(0, 30);
ax_line.legend(['Number of Rainy Days', 'Online F&B Sales Proportion']);

# %% [markdown]
# This looks like a very strong correlation. Trends look very similar, especially June to October. Also, June and November have more rainy days than other months. We can try to use a scatter plot to investigate further.

# %%
df_fnb_rainyday = df.groupby('month')[['no_of_rainy_days', 'online_f&b_sales_proportion']].mean()
df_fnb_rainyday = df_fnb_rainyday.reset_index()
df_fnb_rainyday_numeric = df_fnb_rainyday.drop(columns=['month'])
ax_special = sns.heatmap(df_fnb_rainyday_numeric.corr(), annot=True, fmt=".3f");
ax_special.set_title("Correlation Matrix");

# %%
scatter_special = df_fnb_rainyday_numeric.plot(y='online_f&b_sales_proportion', fontsize=12, x='no_of_rainy_days', ylabel='Online F&B Sales Proportion', xlabel='Number of Rainy Days', kind='scatter', 
           color='indigo', figsize=(15,7), s=100);
scatter_special.set_title('Scatter Plot between Number of Rainy Days & Online F&B Sales Proportion', fontsize=21);

# %% [markdown]
# The correlation value is 0.493, which shows a moderate positive correlation. The scatter plot can be seen above.

# %%
ax_covid = df[12:18].plot(kind='bar', x='year-month', rot=0, y='online_f&b_sales_proportion', ylabel='Online F&B Sales Proportion', xlabel='Year-Month', figsize=(15,8));
ax_covid.set_title('Online F&B Sales Proportion from Jan 2020 to June 2020', fontsize=21);
ax_covid.legend(['Online F&B Sales Proportion']);

# %% [markdown]
# External factors such as the [2020 to 2021 Circuit Breaker measures](https://en.wikipedia.org/wiki/2020-21_Singapore_circuit_breaker_measures) might have affected the data because there was a spike in the online F&B sales proportion from March 2020 to April 2020 (see bar chart above), which was the start of "Lockdown" in Singapore. We will split the time period into three parts:
# 1) January 2019 to March 2020 (Before Circuit Breaker measures)
# 2) April 2020 to July 2021 (During Circuit Breaker measures)
# 3) August 2021 to August 2022 (After Circuit Breaker measures)

# %%
df_pre_lockdown = df[:15] # dataframe before circuit breaker
df_in_lockdown = df[15:31] # dataframe during circuit breaker
df_post_lockdown = df[31:] # dataframe after circuit breaker

# %%
df_pre_lockdown_num = df_pre_lockdown.drop(columns=['year-month','year','month']) # drop the columns with string types
df_pre_cor = df_pre_lockdown_num.corr()
ax_pre = sns.heatmap(df_pre_cor, annot=True, fmt=".3f"); # correlation from 2019 Jan to 2020 Mar
ax_pre.set_title("Correlation Matrix between variables (Pre Circuit Breaker)");

# %% [markdown]
# Before Circuit Breaker (above heatmap), there seems to be little correlation between Online F&B sales proportion and each of the other variables. But we will analyse the correlation between Max Rainfall in a Day and Online F&B sales proportion using a scatter plot. Their correlation value is 0.179, which is a weak positive correlation.

# %%
scatter_before = df_pre_lockdown.plot(y='online_f&b_sales_proportion', x='maximum_rainfall_in_a_day', ylabel='Online F&B Sales Proportion', xlabel='Max Rainfall in a Day', kind='scatter', 
           color='dodgerblue', figsize=(15,7), s=100);
scatter_before.set_title('Scatter Plot between Max Rainfall in a Day & Online F&B Sales Proportion', fontsize=21);
# Scatter plot of max rainfall in a day and online f&b sales proportion BEFORE CIRCUIT BREAKER

# %%
df_in_lockdown_num = df_in_lockdown.drop(columns=['year-month','year','month']) # drop the columns with string types
df_in_cor = df_in_lockdown_num.corr()
ax_in = sns.heatmap(df_in_cor, annot=True, fmt=".3f"); # correlation from 2020 Apr to 2021 Jul
ax_in.set_title("Correlation Matrix between variables (During Circuit Breaker)");

# %% [markdown]
# During Circuit Breaker (above heatmap), the correlation value between Online F&B sales proportion and Wet Bulb Temperature is 0.754, which is considered a strong positive correlation. Additionally, the correlation value between Online F&B sales proportion and Surface Air Temperature is 0.692, which is also a strong positive correlation. We can investigate these correlations further using scatter plots.

# %%
scatter_in_wb = df_in_lockdown.plot(y='online_f&b_sales_proportion', x='wet_bulb_temperature', ylabel='Online F&B Sales Proportion', xlabel='Wet Bulb Temperature', kind='scatter', 
           color='red', figsize=(15,7), s=100);
scatter_in_wb.set_title('Scatter Plot between Wet Bulb Temperature & Online F&B Sales Proportion', fontsize=21);
# Scatter plot of wet bulb temperature and online f&b sales proportion DURING CIRCUIT BREAKER

# %% [markdown]
# For the area between 24.5 and 25.0 of the Wet Bulb Temperature axis, it might be a "not so extreme" temperature for people to go out to buy food (instead of ordering food online).

# %%
scatter_in_mt = df_in_lockdown.plot(y='online_f&b_sales_proportion', x='mean_temp', ylabel='Online F&B Sales Proportion', xlabel='Mean Surface Air Temperatiure', kind='scatter', 
           color='red', figsize=(15,7), s=100);
scatter_in_mt.set_title('Scatter Plot between Mean Surface Air Temperature & Online F&B Sales Proportion', fontsize=21);
# scatter plot of surface air temperature and online f&b sales proportion DURING CIRCUIT BREAKER

# %%
df_post_lockdown_num = df_post_lockdown.drop(columns=['year-month','year','month']) # drop the columns with string types
df_post_cor = df_post_lockdown_num.corr()
ax_post = sns.heatmap(df_post_cor, annot=True, fmt=".3f"); # correlation from 2021 Jul to 2022 Aug
ax_post.set_title("Correlation Matrix between variables (After Circuit Breaker)");

# %% [markdown]
# After Circuit Breaker (above heatmap), the correlation value between Online F&B sales and Total Rainfall is 0.533, which is a moderate positive correlation. We can investigate this correlation further using a scatter plot.

# %%
scatter_post = df_post_lockdown.plot(y='online_f&b_sales_proportion', x='total_rainfall', ylabel='Online F&B Sales Proportion', xlabel='Total Rainfall', kind='scatter', 
           color='green', figsize=(15,7), s=100);
scatter_post.set_title('Scatter Plot between Total Rainfall & Online F&B Sales Proportion', fontsize=21);
# scatter plot of total rainfall and online f&b sales proportion AFTER CIRCUIT BREAKER

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
#
# Over a year (Jan-Dec), very similar trends observed between number of rainy days and online F&B sales proportion. More rainy days are expected in June and November. Before Circuit Breaker, as max rainfall in a day increases, online F&B sales proportion increase slightly. During Circuit Breaker, there was a strong correlation between wet-bulb/surface-air temperature and online F&B sales proportion (But external factor, Circuit Breaker, should be considered). After Circuit Breaker, as total rainfall and maximum rainfall in a day rises, there was a moderate rise in online F&B sales proportion.
#
# Based on our data, it is likely that rainy days will boost online F&B sales proportion. Thus, more resources such as containers for packing food and delivery riders can be prepared as well. Additionally, the F&B businesses can ensure that the online order application system is able to handle an increase in the amount of orders.
#
# For future research purposes, we might want to use the data for online F&B sales "numbers" instead of "proportion" to see if weather changes affect online F&B sales numbers. Also, a longer timeframe, instead of just 2019 to 2022, can be used for future analysis. This is so that we have a better interpretation of the trends throughout a year.
